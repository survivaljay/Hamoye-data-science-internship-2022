# %%
# import the required libraries

import pandas as pd
import numpy as np

# %%
# Read in the required dataset


data = pd.read_csv('Big Mart Sales Prediction Train.csv')

data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Check the number of rows and columns
data.shape
# Out:
# (8523, 12)

# %%
# Check additional information about the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ## DESCRIBING/SORTING DATA

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# Statsitical inference of the categorical Dataset
data.describe(include = 'object')
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                5                     16
# top              FDG33          Low Fat  Fruits and Vegetables
# freq                10             5089                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        6113                 8523               8523
# unique                10           3                    3                  4
# top               OUT027      Medium               Tier 3  Supermarket Type1
# freq                 935        2793                 3350               5577

# %% [markdown]
# ## SORT FUNCTION

# %%
# This sort the dataframe based on the Educational status, i.e all graduates come first before the non-graduates.
#data.sort_values("Education")
data.sort_values('Item_Identifier', ascending = False)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2839           NCZ54        14.65          Low Fat         0.083359
# 214            NCZ54        14.65          Low Fat         0.000000
# 7166           NCZ54          NaN          Low Fat         0.145952
# 1969           NCZ54        14.65          Low Fat         0.083528
# 1896           NCZ54          NaN          Low Fat         0.082956
# ...              ...          ...              ...              ...
# 118            DRA12        11.60          Low Fat         0.041178
# 7467           DRA12        11.60          Low Fat         0.041113
# 8043           DRA12        11.60          Low Fat         0.068535
# 1197           DRA12        11.60          Low Fat         0.000000
# 1693           DRA12        11.60               LF         0.000000
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 2839    Household  161.9552            OUT046                       1997
# ...

# %%
data.loc[(data['Item_Fat_Content'] == 'Low Fat') & (data['Outlet_Establishment_Year'] == 2002)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 33             FDO23       17.850          Low Fat         0.000000
# 46             NCP05       19.600          Low Fat         0.000000
# 47             FDV49       10.000          Low Fat         0.025880
# 56             NCX54        9.195          Low Fat         0.048157
# 68             DRH37       17.600          Low Fat         0.041701
# ...              ...          ...              ...              ...
# 8468           FDB20        7.720          Low Fat         0.052086
# 8474           NCJ42       19.750          Low Fat         0.014330
# 8476           NCO41       12.500          Low Fat         0.018887
# 8483           DRI11        8.260          Low Fat         0.034474
# 8502           NCH43        8.420          Low Fat         0.070712
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 33                   Breads   93.1436            OUT045
# ...

# %%
# Searching for keywords
data.loc[data['Item_Type'].str.contains('tables')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07        19.20          Regular         0.000000
# 10             FDY07        11.80          Low Fat         0.000000
# 12             FDX32        15.10          Regular         0.100014
# 14             FDF32        16.35          Low Fat         0.068024
# 36             FDV20          NaN          Regular         0.059512
# ...              ...          ...              ...              ...
# 8490           FDU44          NaN          Regular         0.102296
# 8497           FDT08        13.65          Low Fat         0.049209
# 8503           FDQ44        20.50          Low Fat         0.036133
# 8508           FDW31        11.35          Regular         0.043246
# 8509           FDG45         8.10          Low Fat         0.214306
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %% [markdown]
# ## AGGREGATE STATISTICS (GROUPBY)
# This allows pandas to be able to perform a lot more statistical operations with datadrame set

# %%
data.groupby(['Item_Fat_Content']).count()
# Out:
#                   Item_Identifier  Item_Weight  Item_Visibility  Item_Type  \
# Item_Fat_Content
# LF                            316          260              316        316
# Low Fat                      5089         4222             5089       5089
# Regular                      2889         2388             2889       2889
# low fat                       112           84              112        112
# reg                           117          106              117        117
#
#                   Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Fat_Content
# LF                     316                316                        316
# Low Fat               5089               5089                       5089
# Regular               2889               2889                       2889
# low fat                112                112                        112
# reg                    117                117                        117
#
# ...

# %%
data.groupby(['Item_Fat_Content']).mean()['Item_Outlet_Sales']
# Out:
# Item_Fat_Content
# LF         2073.551928
# Low Fat    2164.477336
# Regular    2235.186702
# low fat    2087.740737
# reg        1962.192268
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# ## CHECKING FOR DUPLICATE ROWS/COLUMNS¶

# %%
duplicated = data.duplicated().sum()
if duplicated:
    print('Duplicate rows in Dataset are {}'.format(duplicated))
else:
    print('Dataset contains no duplicate values')
# Out:
# Dataset contains no duplicate values

# %% [markdown]
# ## HANDLING MISSING DATA¶

# %%
# Checking for missing values
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
# This function returns False Statement if at least one column has a missing value
data.notnull().all().all()
# Out:
# False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# Filling the item weight column
data['Item_Weight'] = data['Item_Weight'].fillna(data['Item_Weight'].mean())
# Filling the outlet size Column
data['Outlet_Size'] = data['Outlet_Size'].fillna(data['Outlet_Size'].mode()[0])

# %%
# This function returns False Statement if at least one column has a missing value
data.notnull().all().all()
# Out:
# True
